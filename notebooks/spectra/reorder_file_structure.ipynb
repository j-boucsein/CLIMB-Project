# %%
import numpy as np
import subprocess
import os
import csv
import shutil
import subprocess
import re

# %%
sim_suite_location = "/vera/u/jerbo/my_ptmp/L25n256_suite"
number_of_gridpoints = 50
gps_to_reorder = []
for i in range(number_of_gridpoints):
    path = sim_suite_location + f"/gridpoint{i}"
    gps_to_reorder.append(path)

gps_to_reorder.append(sim_suite_location + f"/reference_point")  # add the reference run

# %% [raw]
# # delete restart files
# for current_gp in gps_to_reorder:
#     content = os.listdir(current_gp)
#
#     if 'restartfiles' in content and 'snapdir_005' in content:
#         restartfiles_path = current_gp + "/restartfiles"
#         scary_cmd = f"rm -rf {restartfiles_path}"
#         print(scary_cmd)
#         # os.system(scary_cmd)  # this is very scary and probably not the way I should be doing this

# %%
# create the output folders
for current_gp in gps_to_reorder:
    output_dir = current_gp + "/output"
    try:
        os.mkdir(output_dir)
    except FileExistsError:
        print(f"[{output_dir}] already exists")

# %%
# check if all outputfolders were created sucessfully
error_occured = False
for current_gp in gps_to_reorder:
    content = os.listdir(current_gp)
    if 'output' not in content:
        print(f"Error: no output folder in [{current_gp}]")
        error_occured = True

# %%
assert not error_occured, "make sure everything prior worked before continuing"

# %%
# safely move all snaps and groups into output folder 

for current_gp in gps_to_reorder:
    snapdirs_to_move = []
    groups_to_move = []
    
    # src = "/vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint0/snapdir_000/"
    # dst = "/vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint0/output/snapdir_000/"
    print(current_gp)
    for filename in os.listdir(current_gp):
        if re.search("snapdir_*", filename):
            snapdirs_to_move.append(filename)
        if re.search("groups_*", filename):
            groups_to_move.append(filename)
    
    for snap in snapdirs_to_move:
        src = f"{current_gp}/{snap}/"
        dst = f"{current_gp}/output/{snap}/"
        # -a = archive (erhält Rechte, Zeiten, Symlinks)
        # -v = verbose
        # --remove-source-files = löscht Quelldateien nach erfolgreichem Kopieren
        cmd = ["rsync", "-av", "--remove-source-files", src, dst]
        subprocess.run(cmd, check=True)

    for group in groups_to_move:
        src = f"{current_gp}/{group}/"
        dst = f"{current_gp}/output/{group}/"
        # -a = archive (erhält Rechte, Zeiten, Symlinks)
        # -v = verbose
        # --remove-source-files = löscht Quelldateien nach erfolgreichem Kopieren
        cmd = ["rsync", "-av", "--remove-source-files", src, dst]
        subprocess.run(cmd, check=True)
# Out:
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint0
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint1
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 61 bytes  received 19 bytes  160,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint2
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint3
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint4
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint5
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint6
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint7
# sending incremental file list
# ./
#
# sent 60 bytes  received 19 bytes  158,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 61 bytes  received 19 bytes  160,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint8
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint9
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 55 bytes  received 19 bytes  148,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint10
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 61 bytes  received 19 bytes  160,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint11
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint12
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint13
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint14
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint15
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint16
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint17
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint18
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 61 bytes  received 19 bytes  160,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint19
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint20
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint21
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint22
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 61 bytes  received 19 bytes  160,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  50,67 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint23
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint24
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 56 bytes  received 19 bytes  150,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25
# sending incremental file list
# ./
#
# sent 57 bytes  received 19 bytes  152,00 bytes/sec
# total size is 0  speedup is 0,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/snapdir_000
# ./
# snap_000.0.hdf5
# snap_000.1.hdf5
# snap_000.2.hdf5
# snap_000.3.hdf5
# snap_000.4.hdf5
# snap_000.5.hdf5
# snap_000.6.hdf5
# snap_000.7.hdf5
#
# sent 5.169.062.850 bytes  received 452 bytes  356.487.124,28 bytes/sec
# total size is 5.167.800.640  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/snapdir_004
# ./
# snap_004.0.hdf5
# snap_004.1.hdf5
# snap_004.2.hdf5
# snap_004.3.hdf5
# snap_004.4.hdf5
# snap_004.5.hdf5
# snap_004.6.hdf5
# snap_004.7.hdf5
#
# sent 5.141.064.094 bytes  received 452 bytes  331.681.583,61 bytes/sec
# total size is 5.139.808.700  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/snapdir_001
# ./
# snap_001.0.hdf5
# snap_001.1.hdf5
# snap_001.2.hdf5
# snap_001.3.hdf5
# snap_001.4.hdf5
# snap_001.5.hdf5
# snap_001.6.hdf5
# snap_001.7.hdf5
#
# sent 5.155.808.281 bytes  received 452 bytes  355.573.016,07 bytes/sec
# total size is 5.154.549.300  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/snapdir_005
# ./
# snap_005.0.hdf5
# snap_005.1.hdf5
# snap_005.2.hdf5
# snap_005.3.hdf5
# snap_005.4.hdf5
# snap_005.5.hdf5
# snap_005.6.hdf5
# snap_005.7.hdf5
#
# sent 5.136.998.015 bytes  received 452 bytes  354.275.756,34 bytes/sec
# total size is 5.135.743.624  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/snapdir_003
# ./
# snap_003.0.hdf5
# snap_003.1.hdf5
# snap_003.2.hdf5
# snap_003.3.hdf5
# snap_003.4.hdf5
# snap_003.5.hdf5
# snap_003.6.hdf5
# snap_003.7.hdf5
#
# sent 5.139.135.035 bytes  received 452 bytes  331.557.128,19 bytes/sec
# total size is 5.137.880.128  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/groups_005
# ./
# fof_subhalo_tab_005.0.hdf5
# fof_subhalo_tab_005.1.hdf5
# fof_subhalo_tab_005.2.hdf5
# fof_subhalo_tab_005.3.hdf5
# fof_subhalo_tab_005.4.hdf5
# fof_subhalo_tab_005.5.hdf5
# fof_subhalo_tab_005.6.hdf5
# fof_subhalo_tab_005.7.hdf5
#
# sent 13.603.456 bytes  received 451 bytes  27.207.814,00 bytes/sec
# total size is 13.599.592  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/groups_002
# ./
# fof_subhalo_tab_002.0.hdf5
# fof_subhalo_tab_002.1.hdf5
# fof_subhalo_tab_002.2.hdf5
# fof_subhalo_tab_002.3.hdf5
# fof_subhalo_tab_002.4.hdf5
# fof_subhalo_tab_002.5.hdf5
# fof_subhalo_tab_002.6.hdf5
# fof_subhalo_tab_002.7.hdf5
#
# sent 14.303.592 bytes  received 451 bytes  9.536.028,67 bytes/sec
# total size is 14.299.552  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/groups_004
# ./
# fof_subhalo_tab_004.0.hdf5
# fof_subhalo_tab_004.1.hdf5
# fof_subhalo_tab_004.2.hdf5
# fof_subhalo_tab_004.3.hdf5
# fof_subhalo_tab_004.4.hdf5
# fof_subhalo_tab_004.5.hdf5
# fof_subhalo_tab_004.6.hdf5
# fof_subhalo_tab_004.7.hdf5
#
# sent 14.846.991 bytes  received 451 bytes  29.694.884,00 bytes/sec
# total size is 14.842.832  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/groups_001
# ./
# fof_subhalo_tab_001.0.hdf5
# fof_subhalo_tab_001.1.hdf5
# fof_subhalo_tab_001.2.hdf5
# fof_subhalo_tab_001.3.hdf5
# fof_subhalo_tab_001.4.hdf5
# fof_subhalo_tab_001.5.hdf5
# fof_subhalo_tab_001.6.hdf5
# fof_subhalo_tab_001.7.hdf5
#
# sent 11.661.228 bytes  received 451 bytes  7.774.452,67 bytes/sec
# total size is 11.657.844  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/groups_003
# ./
# fof_subhalo_tab_003.0.hdf5
# fof_subhalo_tab_003.1.hdf5
# fof_subhalo_tab_003.2.hdf5
# fof_subhalo_tab_003.3.hdf5
# fof_subhalo_tab_003.4.hdf5
# fof_subhalo_tab_003.5.hdf5
# fof_subhalo_tab_003.6.hdf5
# fof_subhalo_tab_003.7.hdf5
#
# sent 15.207.252 bytes  received 451 bytes  30.415.406,00 bytes/sec
# total size is 15.203.004  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint25/output/groups_000
# ./
# fof_subhalo_tab_000.0.hdf5
# fof_subhalo_tab_000.1.hdf5
# fof_subhalo_tab_000.2.hdf5
# fof_subhalo_tab_000.3.hdf5
# fof_subhalo_tab_000.4.hdf5
# fof_subhalo_tab_000.5.hdf5
# fof_subhalo_tab_000.6.hdf5
# fof_subhalo_tab_000.7.hdf5
#
# sent 207.752 bytes  received 451 bytes  416.406,00 bytes/sec
# total size is 207.168  speedup is 1,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/snapdir_002
# ./
# snap_002.0.hdf5
# snap_002.1.hdf5
# snap_002.2.hdf5
# snap_002.3.hdf5
# snap_002.4.hdf5
# snap_002.5.hdf5
# snap_002.6.hdf5
# snap_002.7.hdf5
#
# sent 5.141.021.773 bytes  received 452 bytes  331.678.853,23 bytes/sec
# total size is 5.139.766.392  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/snapdir_000
# ./
# snap_000.0.hdf5
# snap_000.1.hdf5
# snap_000.2.hdf5
# snap_000.3.hdf5
# snap_000.4.hdf5
# snap_000.5.hdf5
# snap_000.6.hdf5
# snap_000.7.hdf5
#
# sent 5.169.062.857 bytes  received 452 bytes  313.276.564,18 bytes/sec
# total size is 5.167.800.640  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/snapdir_004
# ./
# snap_004.0.hdf5
# snap_004.1.hdf5
# snap_004.2.hdf5
# snap_004.3.hdf5
# snap_004.4.hdf5
# snap_004.5.hdf5
# snap_004.6.hdf5
# snap_004.7.hdf5
#
# sent 5.159.524.733 bytes  received 452 bytes  355.829.323,10 bytes/sec
# total size is 5.158.264.836  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/snapdir_001
# ./
# snap_001.0.hdf5
# snap_001.1.hdf5
# snap_001.2.hdf5
# snap_001.3.hdf5
# snap_001.4.hdf5
# snap_001.5.hdf5
# snap_001.6.hdf5
# snap_001.7.hdf5
#
# sent 5.145.827.973 bytes  received 452 bytes  354.884.718,97 bytes/sec
# total size is 5.144.571.432  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/snapdir_005
# ./
# snap_005.0.hdf5
# snap_005.1.hdf5
# snap_005.2.hdf5
# snap_005.3.hdf5
# snap_005.4.hdf5
# snap_005.5.hdf5
# snap_005.6.hdf5
# snap_005.7.hdf5
#
# sent 5.123.289.280 bytes  received 452 bytes  353.330.326,34 bytes/sec
# total size is 5.122.038.228  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/snapdir_003
# ./
# snap_003.0.hdf5
# snap_003.1.hdf5
# snap_003.2.hdf5
# snap_003.3.hdf5
# snap_003.4.hdf5
# snap_003.5.hdf5
# snap_003.6.hdf5
# snap_003.7.hdf5
#
# sent 5.154.430.595 bytes  received 452 bytes  355.478.003,24 bytes/sec
# total size is 5.153.171.960  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/groups_005
# ./
# fof_subhalo_tab_005.0.hdf5
# fof_subhalo_tab_005.1.hdf5
# fof_subhalo_tab_005.2.hdf5
# fof_subhalo_tab_005.3.hdf5
# fof_subhalo_tab_005.4.hdf5
# fof_subhalo_tab_005.5.hdf5
# fof_subhalo_tab_005.6.hdf5
# fof_subhalo_tab_005.7.hdf5
#
# sent 17.048.712 bytes  received 451 bytes  11.366.108,67 bytes/sec
# total size is 17.044.016  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/groups_002
# ./
# fof_subhalo_tab_002.0.hdf5
# fof_subhalo_tab_002.1.hdf5
# fof_subhalo_tab_002.2.hdf5
# fof_subhalo_tab_002.3.hdf5
# fof_subhalo_tab_002.4.hdf5
# fof_subhalo_tab_002.5.hdf5
# fof_subhalo_tab_002.6.hdf5
# fof_subhalo_tab_002.7.hdf5
#
# sent 23.615.484 bytes  received 451 bytes  47.231.870,00 bytes/sec
# total size is 23.609.188  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/groups_004
# ./
# fof_subhalo_tab_004.0.hdf5
# fof_subhalo_tab_004.1.hdf5
# fof_subhalo_tab_004.2.hdf5
# fof_subhalo_tab_004.3.hdf5
# fof_subhalo_tab_004.4.hdf5
# fof_subhalo_tab_004.5.hdf5
# fof_subhalo_tab_004.6.hdf5
# fof_subhalo_tab_004.7.hdf5
#
# sent 20.376.143 bytes  received 451 bytes  13.584.396,00 bytes/sec
# total size is 20.370.640  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/groups_001
# ./
# fof_subhalo_tab_001.0.hdf5
# fof_subhalo_tab_001.1.hdf5
# fof_subhalo_tab_001.2.hdf5
# fof_subhalo_tab_001.3.hdf5
# fof_subhalo_tab_001.4.hdf5
# fof_subhalo_tab_001.5.hdf5
# fof_subhalo_tab_001.6.hdf5
# fof_subhalo_tab_001.7.hdf5
#
# sent 22.860.512 bytes  received 451 bytes  45.721.926,00 bytes/sec
# total size is 22.854.400  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/groups_003
# ./
# fof_subhalo_tab_003.0.hdf5
# fof_subhalo_tab_003.1.hdf5
# fof_subhalo_tab_003.2.hdf5
# fof_subhalo_tab_003.3.hdf5
# fof_subhalo_tab_003.4.hdf5
# fof_subhalo_tab_003.5.hdf5
# fof_subhalo_tab_003.6.hdf5
# fof_subhalo_tab_003.7.hdf5
#
# sent 22.628.660 bytes  received 451 bytes  15.086.074,00 bytes/sec
# total size is 22.622.604  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint26/output/groups_000
# ./
# fof_subhalo_tab_000.0.hdf5
# fof_subhalo_tab_000.1.hdf5
# fof_subhalo_tab_000.2.hdf5
# fof_subhalo_tab_000.3.hdf5
# fof_subhalo_tab_000.4.hdf5
# fof_subhalo_tab_000.5.hdf5
# fof_subhalo_tab_000.6.hdf5
# fof_subhalo_tab_000.7.hdf5
#
# sent 207.748 bytes  received 451 bytes  416.398,00 bytes/sec
# total size is 207.168  speedup is 1,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint27
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint27/output/snapdir_002
# ./
# snap_002.0.hdf5
# snap_002.1.hdf5
# snap_002.2.hdf5
# snap_002.3.hdf5
# snap_002.4.hdf5
# snap_002.5.hdf5
# snap_002.6.hdf5
# snap_002.7.hdf5
#
# sent 5.135.512.559 bytes  received 452 bytes  331.323.420,06 bytes/sec
# total size is 5.134.258.544  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint27/output/snapdir_000
# ./
# snap_000.0.hdf5
# snap_000.1.hdf5
# snap_000.2.hdf5
# snap_000.3.hdf5
# snap_000.4.hdf5
# snap_000.5.hdf5
# snap_000.6.hdf5
# snap_000.7.hdf5
#
# sent 5.169.062.871 bytes  received 452 bytes  295.375.047,03 bytes/sec
# total size is 5.167.800.640  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint27/output/snapdir_004
# ./
# snap_004.0.hdf5
# snap_004.1.hdf5
# snap_004.2.hdf5
# snap_004.3.hdf5
# snap_004.4.hdf5
# snap_004.5.hdf5
# snap_004.6.hdf5
# snap_004.7.hdf5
#
# sent 5.139.032.085 bytes  received 452 bytes  331.550.486,26 bytes/sec
# total size is 5.137.777.192  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint27/output/snapdir_001
# ./
# snap_001.0.hdf5
# snap_001.1.hdf5
# snap_001.2.hdf5
# snap_001.3.hdf5
# snap_001.4.hdf5
# snap_001.5.hdf5
# snap_001.6.hdf5
# snap_001.7.hdf5
#
# sent 5.148.625.736 bytes  received 452 bytes  355.077.668,14 bytes/sec
# total size is 5.147.368.508  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint27/output/snapdir_005
# ./
# snap_005.0.hdf5
# snap_005.1.hdf5
# snap_005.2.hdf5
# snap_005.3.hdf5
# snap_005.4.hdf5
# snap_005.5.hdf5
# snap_005.6.hdf5
# snap_005.7.hdf5
#
# sent 5.141.545.840 bytes  received 452 bytes  354.589.399,45 bytes/sec
# total size is 5.140.290.324  speedup is 1,00
# sending incremental file list
# ...
# ./
# fof_subhalo_tab_002.0.hdf5
# fof_subhalo_tab_002.1.hdf5
# fof_subhalo_tab_002.2.hdf5
# fof_subhalo_tab_002.3.hdf5
# fof_subhalo_tab_002.4.hdf5
# fof_subhalo_tab_002.5.hdf5
# fof_subhalo_tab_002.6.hdf5
# fof_subhalo_tab_002.7.hdf5
#
# sent 10.419.852 bytes  received 451 bytes  6.946.868,67 bytes/sec
# total size is 10.416.764  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint47/output/groups_004
# ./
# fof_subhalo_tab_004.0.hdf5
# fof_subhalo_tab_004.1.hdf5
# fof_subhalo_tab_004.2.hdf5
# fof_subhalo_tab_004.3.hdf5
# fof_subhalo_tab_004.4.hdf5
# fof_subhalo_tab_004.5.hdf5
# fof_subhalo_tab_004.6.hdf5
# fof_subhalo_tab_004.7.hdf5
#
# sent 12.306.428 bytes  received 451 bytes  24.613.758,00 bytes/sec
# total size is 12.302.892  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint47/output/groups_001
# ./
# fof_subhalo_tab_001.0.hdf5
# fof_subhalo_tab_001.1.hdf5
# fof_subhalo_tab_001.2.hdf5
# fof_subhalo_tab_001.3.hdf5
# fof_subhalo_tab_001.4.hdf5
# fof_subhalo_tab_001.5.hdf5
# fof_subhalo_tab_001.6.hdf5
# fof_subhalo_tab_001.7.hdf5
#
# sent 7.745.604 bytes  received 451 bytes  15.492.110,00 bytes/sec
# total size is 7.743.188  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint47/output/groups_003
# ./
# fof_subhalo_tab_003.0.hdf5
# fof_subhalo_tab_003.1.hdf5
# fof_subhalo_tab_003.2.hdf5
# fof_subhalo_tab_003.3.hdf5
# fof_subhalo_tab_003.4.hdf5
# fof_subhalo_tab_003.5.hdf5
# fof_subhalo_tab_003.6.hdf5
# fof_subhalo_tab_003.7.hdf5
#
# sent 11.901.279 bytes  received 451 bytes  7.934.486,67 bytes/sec
# total size is 11.897.848  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint47/output/groups_000
# ./
# fof_subhalo_tab_000.0.hdf5
# fof_subhalo_tab_000.1.hdf5
# fof_subhalo_tab_000.2.hdf5
# fof_subhalo_tab_000.3.hdf5
# fof_subhalo_tab_000.4.hdf5
# fof_subhalo_tab_000.5.hdf5
# fof_subhalo_tab_000.6.hdf5
# fof_subhalo_tab_000.7.hdf5
#
# sent 207.752 bytes  received 451 bytes  416.406,00 bytes/sec
# total size is 207.168  speedup is 1,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/snapdir_002
# ./
# snap_002.0.hdf5
# snap_002.1.hdf5
# snap_002.2.hdf5
# snap_002.3.hdf5
# snap_002.4.hdf5
# snap_002.5.hdf5
# snap_002.6.hdf5
# snap_002.7.hdf5
#
# sent 5.136.683.741 bytes  received 452 bytes  354.254.082,28 bytes/sec
# total size is 5.135.429.416  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/snapdir_000
# ./
# snap_000.0.hdf5
# snap_000.1.hdf5
# snap_000.2.hdf5
# snap_000.3.hdf5
# snap_000.4.hdf5
# snap_000.5.hdf5
# snap_000.6.hdf5
# snap_000.7.hdf5
#
# sent 5.169.062.863 bytes  received 452 bytes  356.487.125,17 bytes/sec
# total size is 5.167.800.640  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/snapdir_004
# ./
# snap_004.0.hdf5
# snap_004.1.hdf5
# snap_004.2.hdf5
# snap_004.3.hdf5
# snap_004.4.hdf5
# snap_004.5.hdf5
# snap_004.6.hdf5
# snap_004.7.hdf5
#
# sent 5.150.839.537 bytes  received 452 bytes  163.518.729,81 bytes/sec
# total size is 5.149.581.764  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/snapdir_001
# ./
# snap_001.0.hdf5
# snap_001.1.hdf5
# snap_001.2.hdf5
# snap_001.3.hdf5
# snap_001.4.hdf5
# snap_001.5.hdf5
# snap_001.6.hdf5
# snap_001.7.hdf5
#
# sent 5.143.663.100 bytes  received 452 bytes  209.945.451,10 bytes/sec
# total size is 5.142.407.068  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/snapdir_003
# ./
# snap_003.0.hdf5
# snap_003.1.hdf5
# snap_003.2.hdf5
# snap_003.3.hdf5
# snap_003.4.hdf5
# snap_003.5.hdf5
# snap_003.6.hdf5
# snap_003.7.hdf5
#
# sent 5.149.704.825 bytes  received 452 bytes  294.268.872,97 bytes/sec
# total size is 5.148.447.320  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/groups_002
# ./
# fof_subhalo_tab_002.0.hdf5
# fof_subhalo_tab_002.1.hdf5
# fof_subhalo_tab_002.2.hdf5
# fof_subhalo_tab_002.3.hdf5
# fof_subhalo_tab_002.4.hdf5
# fof_subhalo_tab_002.5.hdf5
# fof_subhalo_tab_002.6.hdf5
# fof_subhalo_tab_002.7.hdf5
#
# sent 25.510.492 bytes  received 451 bytes  51.021.886,00 bytes/sec
# total size is 25.503.724  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/groups_004
# ./
# fof_subhalo_tab_004.0.hdf5
# fof_subhalo_tab_004.1.hdf5
# fof_subhalo_tab_004.2.hdf5
# fof_subhalo_tab_004.3.hdf5
# fof_subhalo_tab_004.4.hdf5
# fof_subhalo_tab_004.5.hdf5
# fof_subhalo_tab_004.6.hdf5
# fof_subhalo_tab_004.7.hdf5
#
# sent 21.271.892 bytes  received 451 bytes  14.181.562,00 bytes/sec
# total size is 21.266.172  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/groups_001
# ./
# fof_subhalo_tab_001.0.hdf5
# fof_subhalo_tab_001.1.hdf5
# fof_subhalo_tab_001.2.hdf5
# fof_subhalo_tab_001.3.hdf5
# fof_subhalo_tab_001.4.hdf5
# fof_subhalo_tab_001.5.hdf5
# fof_subhalo_tab_001.6.hdf5
# fof_subhalo_tab_001.7.hdf5
#
# sent 24.563.672 bytes  received 451 bytes  16.376.082,00 bytes/sec
# total size is 24.557.144  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/groups_003
# ./
# fof_subhalo_tab_003.0.hdf5
# fof_subhalo_tab_003.1.hdf5
# fof_subhalo_tab_003.2.hdf5
# fof_subhalo_tab_003.3.hdf5
# fof_subhalo_tab_003.4.hdf5
# fof_subhalo_tab_003.5.hdf5
# fof_subhalo_tab_003.6.hdf5
# fof_subhalo_tab_003.7.hdf5
#
# sent 24.200.055 bytes  received 451 bytes  48.401.012,00 bytes/sec
# total size is 24.193.624  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint48/output/groups_000
# ./
# fof_subhalo_tab_000.0.hdf5
# fof_subhalo_tab_000.1.hdf5
# fof_subhalo_tab_000.2.hdf5
# fof_subhalo_tab_000.3.hdf5
# fof_subhalo_tab_000.4.hdf5
# fof_subhalo_tab_000.5.hdf5
# fof_subhalo_tab_000.6.hdf5
# fof_subhalo_tab_000.7.hdf5
#
# sent 207.752 bytes  received 451 bytes  416.406,00 bytes/sec
# total size is 207.168  speedup is 1,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/snapdir_002
# ./
# snap_002.0.hdf5
# snap_002.1.hdf5
# snap_002.2.hdf5
# snap_002.3.hdf5
# snap_002.4.hdf5
# snap_002.5.hdf5
# snap_002.6.hdf5
# snap_002.7.hdf5
#
# sent 5.147.788.544 bytes  received 452 bytes  355.019.930,76 bytes/sec
# total size is 5.146.531.528  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/snapdir_000
# ./
# snap_000.0.hdf5
# snap_000.1.hdf5
# snap_000.2.hdf5
# snap_000.3.hdf5
# snap_000.4.hdf5
# snap_000.5.hdf5
# snap_000.6.hdf5
# snap_000.7.hdf5
#
# sent 5.169.062.860 bytes  received 452 bytes  356.487.124,97 bytes/sec
# total size is 5.167.800.640  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/snapdir_004
# ./
# snap_004.0.hdf5
# snap_004.1.hdf5
# snap_004.2.hdf5
# snap_004.3.hdf5
# snap_004.4.hdf5
# snap_004.5.hdf5
# snap_004.6.hdf5
# snap_004.7.hdf5
#
# sent 5.154.071.969 bytes  received 452 bytes  294.518.424,06 bytes/sec
# total size is 5.152.813.400  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/snapdir_001
# ./
# snap_001.0.hdf5
# snap_001.1.hdf5
# snap_001.2.hdf5
# snap_001.3.hdf5
# snap_001.4.hdf5
# snap_001.5.hdf5
# snap_001.6.hdf5
# snap_001.7.hdf5
#
# sent 5.154.731.522 bytes  received 452 bytes  294.556.112,80 bytes/sec
# total size is 5.153.472.812  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/snapdir_005
# ./
# snap_005.0.hdf5
# snap_005.1.hdf5
# snap_005.2.hdf5
# snap_005.3.hdf5
# snap_005.4.hdf5
# snap_005.5.hdf5
# snap_005.6.hdf5
# snap_005.7.hdf5
#
# sent 5.131.387.121 bytes  received 452 bytes  293.222.147,03 bytes/sec
# total size is 5.130.134.100  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/snapdir_003
# ./
# snap_003.0.hdf5
# snap_003.1.hdf5
# snap_003.2.hdf5
# snap_003.3.hdf5
# snap_003.4.hdf5
# snap_003.5.hdf5
# snap_003.6.hdf5
# snap_003.7.hdf5
#
# sent 5.150.805.454 bytes  received 452 bytes  278.421.940,86 bytes/sec
# total size is 5.149.547.696  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/groups_005
# ./
# fof_subhalo_tab_005.0.hdf5
# fof_subhalo_tab_005.1.hdf5
# fof_subhalo_tab_005.2.hdf5
# fof_subhalo_tab_005.3.hdf5
# fof_subhalo_tab_005.4.hdf5
# fof_subhalo_tab_005.5.hdf5
# fof_subhalo_tab_005.6.hdf5
# fof_subhalo_tab_005.7.hdf5
#
# sent 15.813.979 bytes  received 451 bytes  10.542.953,33 bytes/sec
# total size is 15.809.588  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/groups_002
# ./
# fof_subhalo_tab_002.0.hdf5
# fof_subhalo_tab_002.1.hdf5
# fof_subhalo_tab_002.2.hdf5
# fof_subhalo_tab_002.3.hdf5
# fof_subhalo_tab_002.4.hdf5
# fof_subhalo_tab_002.5.hdf5
# fof_subhalo_tab_002.6.hdf5
# fof_subhalo_tab_002.7.hdf5
#
# sent 17.502.968 bytes  received 451 bytes  11.668.946,00 bytes/sec
# total size is 17.498.152  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/groups_004
# ./
# fof_subhalo_tab_004.0.hdf5
# fof_subhalo_tab_004.1.hdf5
# fof_subhalo_tab_004.2.hdf5
# fof_subhalo_tab_004.3.hdf5
# fof_subhalo_tab_004.4.hdf5
# fof_subhalo_tab_004.5.hdf5
# fof_subhalo_tab_004.6.hdf5
# fof_subhalo_tab_004.7.hdf5
#
# sent 17.431.755 bytes  received 451 bytes  34.864.412,00 bytes/sec
# total size is 17.426.960  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/groups_001
# ./
# fof_subhalo_tab_001.0.hdf5
# fof_subhalo_tab_001.1.hdf5
# fof_subhalo_tab_001.2.hdf5
# fof_subhalo_tab_001.3.hdf5
# fof_subhalo_tab_001.4.hdf5
# fof_subhalo_tab_001.5.hdf5
# fof_subhalo_tab_001.6.hdf5
# fof_subhalo_tab_001.7.hdf5
#
# sent 15.383.528 bytes  received 451 bytes  10.255.986,00 bytes/sec
# total size is 15.379.232  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/groups_003
# ./
# fof_subhalo_tab_003.0.hdf5
# fof_subhalo_tab_003.1.hdf5
# fof_subhalo_tab_003.2.hdf5
# fof_subhalo_tab_003.3.hdf5
# fof_subhalo_tab_003.4.hdf5
# fof_subhalo_tab_003.5.hdf5
# fof_subhalo_tab_003.6.hdf5
# fof_subhalo_tab_003.7.hdf5
#
# sent 18.130.014 bytes  received 451 bytes  36.260.930,00 bytes/sec
# total size is 18.125.056  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/gridpoint49/output/groups_000
# ./
# fof_subhalo_tab_000.0.hdf5
# fof_subhalo_tab_000.1.hdf5
# fof_subhalo_tab_000.2.hdf5
# fof_subhalo_tab_000.3.hdf5
# fof_subhalo_tab_000.4.hdf5
# fof_subhalo_tab_000.5.hdf5
# fof_subhalo_tab_000.6.hdf5
# fof_subhalo_tab_000.7.hdf5
#
# sent 207.752 bytes  received 451 bytes  416.406,00 bytes/sec
# total size is 207.168  speedup is 1,00
# /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/snapdir_002
# ./
# snap_002.0.hdf5
# snap_002.1.hdf5
# snap_002.2.hdf5
# snap_002.3.hdf5
# snap_002.4.hdf5
# snap_002.5.hdf5
# snap_002.6.hdf5
# snap_002.7.hdf5
#
# sent 5.157.185.040 bytes  received 456 bytes  278.766.783,57 bytes/sec
# total size is 5.155.925.712  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/snapdir_000
# ./
# snap_000.0.hdf5
# snap_000.1.hdf5
# snap_000.2.hdf5
# snap_000.3.hdf5
# snap_000.4.hdf5
# snap_000.5.hdf5
# snap_000.6.hdf5
# snap_000.7.hdf5
#
# sent 5.169.062.858 bytes  received 456 bytes  313.276.564,48 bytes/sec
# total size is 5.167.800.640  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/snapdir_004
# ./
# snap_004.0.hdf5
# snap_004.1.hdf5
# snap_004.2.hdf5
# snap_004.3.hdf5
# snap_004.4.hdf5
# snap_004.5.hdf5
# snap_004.6.hdf5
# snap_004.7.hdf5
#
# sent 5.136.130.279 bytes  received 456 bytes  311.280.650,61 bytes/sec
# total size is 5.134.876.084  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/snapdir_001
# ./
# snap_001.0.hdf5
# snap_001.1.hdf5
# snap_001.2.hdf5
# snap_001.3.hdf5
# snap_001.4.hdf5
# snap_001.5.hdf5
# snap_001.6.hdf5
# snap_001.7.hdf5
#
# sent 5.152.360.290 bytes  received 456 bytes  312.264.287,64 bytes/sec
# total size is 5.151.102.140  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/snapdir_005
# ./
# snap_005.0.hdf5
# snap_005.1.hdf5
# snap_005.2.hdf5
# snap_005.3.hdf5
# snap_005.4.hdf5
# snap_005.5.hdf5
# snap_005.6.hdf5
# snap_005.7.hdf5
#
# sent 5.123.486.851 bytes  received 456 bytes  292.770.703,26 bytes/sec
# total size is 5.122.235.744  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/snapdir_003
# ./
# snap_003.0.hdf5
# snap_003.1.hdf5
# snap_003.2.hdf5
# snap_003.3.hdf5
# snap_003.4.hdf5
# snap_003.5.hdf5
# snap_003.6.hdf5
# snap_003.7.hdf5
#
# sent 5.150.819.136 bytes  received 456 bytes  312.170.884,36 bytes/sec
# total size is 5.149.561.360  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/groups_005
# ./
# fof_subhalo_tab_005.0.hdf5
# fof_subhalo_tab_005.1.hdf5
# fof_subhalo_tab_005.2.hdf5
# fof_subhalo_tab_005.3.hdf5
# fof_subhalo_tab_005.4.hdf5
# fof_subhalo_tab_005.5.hdf5
# fof_subhalo_tab_005.6.hdf5
# fof_subhalo_tab_005.7.hdf5
#
# sent 16.337.280 bytes  received 455 bytes  10.891.823,33 bytes/sec
# total size is 16.332.760  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/groups_002
# ./
# fof_subhalo_tab_002.0.hdf5
# fof_subhalo_tab_002.1.hdf5
# fof_subhalo_tab_002.2.hdf5
# fof_subhalo_tab_002.3.hdf5
# fof_subhalo_tab_002.4.hdf5
# fof_subhalo_tab_002.5.hdf5
# fof_subhalo_tab_002.6.hdf5
# fof_subhalo_tab_002.7.hdf5
#
# sent 19.977.062 bytes  received 455 bytes  13.318.344,67 bytes/sec
# total size is 19.971.656  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/groups_004
# ./
# fof_subhalo_tab_004.0.hdf5
# fof_subhalo_tab_004.1.hdf5
# fof_subhalo_tab_004.2.hdf5
# fof_subhalo_tab_004.3.hdf5
# fof_subhalo_tab_004.4.hdf5
# fof_subhalo_tab_004.5.hdf5
# fof_subhalo_tab_004.6.hdf5
# fof_subhalo_tab_004.7.hdf5
#
# sent 17.050.372 bytes  received 455 bytes  34.101.654,00 bytes/sec
# total size is 17.045.680  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/groups_001
# ./
# fof_subhalo_tab_001.0.hdf5
# fof_subhalo_tab_001.1.hdf5
# fof_subhalo_tab_001.2.hdf5
# fof_subhalo_tab_001.3.hdf5
# fof_subhalo_tab_001.4.hdf5
# fof_subhalo_tab_001.5.hdf5
# fof_subhalo_tab_001.6.hdf5
# fof_subhalo_tab_001.7.hdf5
#
# sent 18.800.863 bytes  received 455 bytes  37.602.636,00 bytes/sec
# total size is 18.795.728  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/groups_003
# ./
# fof_subhalo_tab_003.0.hdf5
# fof_subhalo_tab_003.1.hdf5
# fof_subhalo_tab_003.2.hdf5
# fof_subhalo_tab_003.3.hdf5
# fof_subhalo_tab_003.4.hdf5
# fof_subhalo_tab_003.5.hdf5
# fof_subhalo_tab_003.6.hdf5
# fof_subhalo_tab_003.7.hdf5
#
# sent 18.305.516 bytes  received 455 bytes  36.611.942,00 bytes/sec
# total size is 18.300.508  speedup is 1,00
# sending incremental file list
# created directory /vera/u/jerbo/my_ptmp/L25n256_suite/reference_point/output/groups_000
# ./
# fof_subhalo_tab_000.0.hdf5
# fof_subhalo_tab_000.1.hdf5
# fof_subhalo_tab_000.2.hdf5
# fof_subhalo_tab_000.3.hdf5
# fof_subhalo_tab_000.4.hdf5
# fof_subhalo_tab_000.5.hdf5
# fof_subhalo_tab_000.6.hdf5
# fof_subhalo_tab_000.7.hdf5
#
# sent 207.752 bytes  received 455 bytes  416.414,00 bytes/sec
# total size is 207.168  speedup is 1,00

# %%
# move text files to output/txt-files directory
for current_gp in gps_to_reorder:
    src = f"{current_gp}"
    dst = f"{current_gp}/output/txt-files"
    
    # Zielverzeichnis erstellen, falls es noch nicht existiert
    os.makedirs(dst, exist_ok=True)
    
    # Alle Elemente im Quellverzeichnis prüfen
    for name in os.listdir(src):
        src_path = os.path.join(src, name)
        dst_path = os.path.join(dst, name)
    
        # Nur reguläre Dateien verschieben (keine Unterordner!)
        if os.path.isfile(src_path):
            shutil.move(src_path, dst_path)

# %%
# move blackhole_details files to output/txt-files directory
for current_gp in gps_to_reorder:
    src = f"{current_gp}/blackhole_details"
    dst = f"{current_gp}/output/txt-files/blackhole_details"
    
    # Zielverzeichnis erstellen, falls es noch nicht existiert
    os.makedirs(dst, exist_ok=True)
    
    # Alle Elemente im Quellverzeichnis prüfen
    for name in os.listdir(src):
        src_path = os.path.join(src, name)
        dst_path = os.path.join(dst, name)
    
        # Nur reguläre Dateien verschieben (keine Unterordner!)
        if os.path.isfile(src_path):
            shutil.move(src_path, dst_path)

# %%
# move blackhole_mergers files to output/txt-files directory
for current_gp in gps_to_reorder:
    src = f"{current_gp}/blackhole_mergers"
    dst = f"{current_gp}/output/txt-files/blackhole_mergers"
    
    # Zielverzeichnis erstellen, falls es noch nicht existiert
    os.makedirs(dst, exist_ok=True)
    
    # Alle Elemente im Quellverzeichnis prüfen
    for name in os.listdir(src):
        src_path = os.path.join(src, name)
        dst_path = os.path.join(dst, name)
    
        # Nur reguläre Dateien verschieben (keine Unterordner!)
        if os.path.isfile(src_path):
            shutil.move(src_path, dst_path)

# %%
# delete empty folders
subprocess.run(["find", sim_suite_location, "-type", "d", "-empty", "-delete"], check=True)
# Out:
# CompletedProcess(args=['find', '/vera/u/jerbo/my_ptmp/L25n256_suite', '-type', 'd', '-empty', '-delete'], returncode=0)
