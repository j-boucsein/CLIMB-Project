# %%
import os
import csv
import subprocess

# %%
output_location = "/vera/u/jerbo/my_ptmp/L25n128_suite"
run_location = "/vera/u/jerbo/TNG-arepo/run/L25n128_suite"
template_location = run_location + "/template"

# %% [markdown]
# os.mkdir(output_location + "/test")
# os.chdir(output_location)
# os.getcwd()
# print(os.listdir())
# os.rmdir(output_location + "/test")
# print(os.listdir())

# %%
assert False, "This cell is here to stop an accidental run all"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-406df4614ba3> in <module>
# ----> 1 assert False, "This cell is here to stop an accidental run all"
#
# AssertionError: This cell is here to stop an accidental run all

# %%
assert False, "Don't run this again"

######################## read grid file ###########################
cosmo_parameters = []

header = True
with open('grid_lhs_constrained.csv', newline='') as f:
    file = csv.reader(f, delimiter=',')
    for row in file:
        if header:
            header = False
            continue
        cosmo_parameters.append([float(i) for i in row])
        
# cosmo_parameters = cosmo_parameters[:10] # ATTETION: ONLY FOR TESTING!! remove this for finished script

##################### loop over grid points ######################

for counter, (Omega_m, Omega_b, Omega_L, hubble_par) in enumerate(cosmo_parameters):
    print("----------------------------------")
    print("Grid Point Nr.", counter)
    print(f"Omega_m = {Omega_m:.3f}, Omega_b = {Omega_b:.3f}, Omega_L = {Omega_L:.3f}, h = {hubble_par:.3f}")
    
    # create output directory
    output_gridpoint = output_location+f"/gridpoint{counter}"
    os.mkdir(output_gridpoint)
    
    # create run directory
    run_gridpoint = run_location+f"/gridpoint{counter}"
    os.mkdir(run_gridpoint)
    
    # copy template to run directory
    cmd = f"cp -r {template_location}/* {run_gridpoint}"
    os.system(cmd)
    
    # check if all expected files are there
    visible_files_template = [file for file in os.listdir(template_location) if not file.startswith('.')]
    visible_files_run = [file for file in os.listdir(run_gridpoint) if not file.startswith('.')]
    if not visible_files_template == visible_files_run:
        print("Error! -> Copying template failed")
        print("Skipping this gridpoint ...")
        continue
    
    # edit param.txt to match gridpoint values
    path_to_param_file = run_gridpoint + "/param_L25n128.txt"
    
    file_content = []
    with open(path_to_param_file, "r") as file:
        for row in file:
            if "Omega0" in row:
                row = f"Omega0	              {Omega_m:.4f}\n"
            if "OmegaLambda" in row:
                row = f"OmegaLambda           {Omega_L:.4f}\n"
            if "OmegaBaryon" in row:
                row = f"OmegaBaryon           {Omega_b:.4f}\n"
            if "HubbleParam" in row:
                row = f"HubbleParam           {hubble_par:.4f}\n"
            if "OutputDir" in row:
                row = f"OutputDir           {output_gridpoint}\n"
            file_content.append(row)

    with open(path_to_param_file, "w") as file:
        for row in file_content:
            file.write(row)
            
    # check if the edits have worked in 
    error = False
    with open(path_to_param_file, "r") as file:
        for row in file:
            if "Omega0" in row:
                if not row.split()[-1] == f"{Omega_m:.4f}":
                    print(f"Error! -> Omega0 not correctly set in {path_to_param_file}")
                    error = True
            if "OmegaLambda" in row:
                if not row.split()[-1] == f"{Omega_L:.4f}":
                    print(f"Error! -> OmegaL not correctly set in {path_to_param_file}")
                    error = True
            if "OmegaBaryon" in row:
                if not row.split()[-1] == f"{Omega_b:.4f}":
                    print(f"Error! -> OmegaB not correctly set in {path_to_param_file}")
                    error = True
            if "HubbleParam" in row:
                if not row.split()[-1] == f"{hubble_par:.4f}":
                    print(f"Error! -> HubblePar not correctly set in {path_to_param_file}")
                    error = True
            if "OutputDir" in row:
                if not row.split()[-1] == output_gridpoint:
                    print(f"Error! -> OutputDir not correctly set in {path_to_param_file}")
                    error = True
    
    if error:
        print("Skipping this gridpoint ...")
        continue
    else:
        print(f"{path_to_param_file} was edited successfully!")
            
    # edit param_muscic.txt to match gridpoint values
    path_to_param_music_file = run_gridpoint + "/param_music.txt"
    
    file_content = []
    with open(path_to_param_music_file, "r") as file:
        for row in file:
            if "Omega_m" in row:
                row = f"Omega_m           = {Omega_m:.4f}\n"
            if "Omega_L" in row:
                row = f"Omega_L           = {Omega_L:.4f}\n"
            if "Omega_b" in row:
                row = f"Omega_b           = {Omega_b:.4f}\n"
            if "H0" in row:
                row = f"H0                = {100*hubble_par:.2f}\n"
            file_content.append(row)

    with open(path_to_param_music_file, "w") as file:
        for row in file_content:
            file.write(row)
            
    # check if the edits have worked
    error = False
    with open(path_to_param_music_file, "r") as file:
        for row in file:
            if "Omega_m" in row:
                if not row.split()[-1] == f"{Omega_m:.4f}":
                    print(f"Error! -> Omega0 not correctly set in {path_to_param_music_file}")
                    error = True
            if "Omega_L" in row:
                if not row.split()[-1] == f"{Omega_L:.4f}":
                    print(f"Error! -> OmegaL not correctly set in {path_to_param_music_file}")
                    error = True
            if "Omega_b" in row:
                if not row.split()[-1] == f"{Omega_b:.4f}":
                    print(f"Error! -> OmegaB not correctly set in {path_to_param_music_file}")
                    error = True
            if "H0" in row:
                if not row.split()[-1] == f"{100*hubble_par:.2f}":
                    print(f"Error! -> HubblePar not correctly set in {path_to_param_music_file}")
                    error = True
    
    if error:
        print("Skipping this gridpoint ...")
        continue
    else:
        print(f"{path_to_param_music_file} was edited successfully!")
        
    # run custom_create.py to make the initial conditions
    os.chdir(run_gridpoint)
    cmd = f"python3 custom_create.py {run_gridpoint}"
    os.system(cmd)
    
    # check if ics.hdf5 file exists
    files_in_run_dir = os.listdir(run_gridpoint)
    if "ics.hdf5" in files_in_run_dir:
        print("ICs were sucessfully created!")
    else:
        print("Error! -> IC creation failed")
        print("Skipping this gridpoint ...")
        continue
    
    # edit name in script.slurm
    path_to_slurm_script = run_gridpoint + "/script.slurm"
    
    file_content = []
    with open(path_to_slurm_script, "r", encoding="utf-8") as file:
        for row in file:
            if "SBATCH -J" in row:
                row = f"#SBATCH -J CLIMB-GP-{counter}\n"
            file_content.append(row)

    with open(path_to_slurm_script, "w") as file:
        for row in file_content:
            file.write(row)
            
    # submit the job script to slurm
    slurm_script = "script.slurm"
    result = subprocess.run(["sbatch", slurm_script], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    sbatch_output = result.stdout.strip()
    
    with open(run_location+"/slurm_job_ids.txt", "a") as myfile:
        myfile.write(f"{counter}: {sbatch_output}\n")
# Out:
# ----------------------------------
# Grid Point Nr. 0
# Omega_m = 0.378, Omega_b = 0.056, Omega_L = 0.622, h = 0.571
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint0/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint0/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 1
# Omega_m = 0.182, Omega_b = 0.004, Omega_L = 0.818, h = 0.705
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint1/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint1/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 2
# Omega_m = 0.409, Omega_b = 0.098, Omega_L = 0.591, h = 0.828
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint2/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint2/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 3
# Omega_m = 0.348, Omega_b = 0.061, Omega_L = 0.652, h = 0.594
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint3/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint3/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 4
# Omega_m = 0.441, Omega_b = 0.059, Omega_L = 0.559, h = 0.719
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint4/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint4/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 5
# Omega_m = 0.195, Omega_b = 0.046, Omega_L = 0.805, h = 0.688
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint5/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint5/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 6
# Omega_m = 0.421, Omega_b = 0.079, Omega_L = 0.579, h = 0.694
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint6/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint6/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 7
# Omega_m = 0.263, Omega_b = 0.032, Omega_L = 0.737, h = 0.611
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint7/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint7/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 8
# Omega_m = 0.291, Omega_b = 0.077, Omega_L = 0.709, h = 0.751
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint8/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint8/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 9
# Omega_m = 0.201, Omega_b = 0.100, Omega_L = 0.799, h = 0.838
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint9/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint9/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 10
# Omega_m = 0.400, Omega_b = 0.034, Omega_L = 0.600, h = 0.778
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint10/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint10/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 11
# Omega_m = 0.460, Omega_b = 0.087, Omega_L = 0.540, h = 0.658
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint11/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint11/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 12
# Omega_m = 0.292, Omega_b = 0.010, Omega_L = 0.708, h = 0.591
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint12/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint12/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 13
# Omega_m = 0.179, Omega_b = 0.005, Omega_L = 0.821, h = 0.661
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint13/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint13/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 14
# Omega_m = 0.302, Omega_b = 0.083, Omega_L = 0.698, h = 0.644
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint14/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint14/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 15
# Omega_m = 0.348, Omega_b = 0.017, Omega_L = 0.652, h = 0.814
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint15/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint15/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 16
# Omega_m = 0.455, Omega_b = 0.062, Omega_L = 0.545, h = 0.826
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint16/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint16/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 17
# Omega_m = 0.254, Omega_b = 0.064, Omega_L = 0.746, h = 0.757
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint17/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint17/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 18
# Omega_m = 0.230, Omega_b = 0.066, Omega_L = 0.770, h = 0.843
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint18/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint18/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 19
# Omega_m = 0.242, Omega_b = 0.041, Omega_L = 0.758, h = 0.732
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint19/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint19/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 20
# Omega_m = 0.327, Omega_b = 0.020, Omega_L = 0.673, h = 0.801
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint20/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint20/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 21
# Omega_m = 0.158, Omega_b = 0.040, Omega_L = 0.842, h = 0.665
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint21/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint21/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 22
# Omega_m = 0.424, Omega_b = 0.048, Omega_L = 0.576, h = 0.728
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint22/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint22/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 23
# Omega_m = 0.395, Omega_b = 0.037, Omega_L = 0.605, h = 0.632
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint23/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint23/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 24
# Omega_m = 0.197, Omega_b = 0.008, Omega_L = 0.803, h = 0.786
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint24/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint24/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 25
# Omega_m = 0.201, Omega_b = 0.083, Omega_L = 0.799, h = 0.561
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint25/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint25/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 26
# Omega_m = 0.470, Omega_b = 0.089, Omega_L = 0.530, h = 0.564
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint26/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint26/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 27
# Omega_m = 0.287, Omega_b = 0.041, Omega_L = 0.713, h = 0.849
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint27/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint27/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 28
# Omega_m = 0.238, Omega_b = 0.090, Omega_L = 0.762, h = 0.712
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint28/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint28/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 29
# Omega_m = 0.453, Omega_b = 0.055, Omega_L = 0.547, h = 0.583
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint29/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint29/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 30
# Omega_m = 0.333, Omega_b = 0.049, Omega_L = 0.667, h = 0.715
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint30/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint30/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 31
# Omega_m = 0.159, Omega_b = 0.037, Omega_L = 0.841, h = 0.747
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint31/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint31/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 32
# Omega_m = 0.187, Omega_b = 0.075, Omega_L = 0.813, h = 0.790
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint32/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint32/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 33
# Omega_m = 0.306, Omega_b = 0.043, Omega_L = 0.694, h = 0.627
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint33/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint33/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 34
# Omega_m = 0.298, Omega_b = 0.092, Omega_L = 0.702, h = 0.608
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint34/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint34/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 35
# Omega_m = 0.321, Omega_b = 0.029, Omega_L = 0.679, h = 0.617
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint35/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint35/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 36
# Omega_m = 0.371, Omega_b = 0.003, Omega_L = 0.629, h = 0.601
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint36/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint36/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 37
# Omega_m = 0.477, Omega_b = 0.093, Omega_L = 0.523, h = 0.765
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint37/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint37/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 38
# Omega_m = 0.255, Omega_b = 0.057, Omega_L = 0.745, h = 0.686
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint38/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint38/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 39
# Omega_m = 0.138, Omega_b = 0.018, Omega_L = 0.862, h = 0.671
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint39/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint39/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 40
# Omega_m = 0.327, Omega_b = 0.030, Omega_L = 0.673, h = 0.816
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint40/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint40/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 41
# Omega_m = 0.178, Omega_b = 0.077, Omega_L = 0.822, h = 0.638
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint41/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint41/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 42
# Omega_m = 0.142, Omega_b = 0.010, Omega_L = 0.858, h = 0.576
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint42/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint42/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 43
# Omega_m = 0.140, Omega_b = 0.017, Omega_L = 0.860, h = 0.802
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint43/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint43/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 44
# Omega_m = 0.247, Omega_b = 0.023, Omega_L = 0.753, h = 0.681
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint44/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint44/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 45
# Omega_m = 0.356, Omega_b = 0.071, Omega_L = 0.644, h = 0.555
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint45/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint45/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 46
# Omega_m = 0.186, Omega_b = 0.039, Omega_L = 0.814, h = 0.780
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint46/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint46/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 47
# Omega_m = 0.241, Omega_b = 0.005, Omega_L = 0.759, h = 0.739
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint47/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint47/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 48
# Omega_m = 0.264, Omega_b = 0.092, Omega_L = 0.736, h = 0.649
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint48/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint48/param_music.txt was edited successfully!
# ICs were sucessfully created!
# ----------------------------------
# Grid Point Nr. 49
# Omega_m = 0.375, Omega_b = 0.075, Omega_L = 0.625, h = 0.771
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint49/param_L25n128.txt was edited successfully!
# /vera/u/jerbo/TNG-arepo/run/L25n128_suite/gridpoint49/param_music.txt was edited successfully!
# ICs were sucessfully created!

# %%
# check which of the jobs are still pending
restart_job_ids = []
with open(run_location+"/slurm_job_ids.txt", "r") as file:
    for row in file:
        count = int(row.split()[0][:-1])
        job_id = row.split()[-1]
        print("GridPoint", count)
        result = subprocess.run(["sacct", "-j", f"{job_id}"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
        sbatch_output = result.stdout.strip()
        if "PENDING" in sbatch_output:
            print(sbatch_output)
            restart_job_ids.append([count, job_id])
        print("---------------------------------")
# Out:
# GridPoint 0
# ---------------------------------
# GridPoint 1
# ---------------------------------
# GridPoint 2
# ---------------------------------
# GridPoint 3
# ---------------------------------
# GridPoint 4
# ---------------------------------
# GridPoint 5
# ---------------------------------
# GridPoint 6
# ---------------------------------
# GridPoint 7
# ---------------------------------
# GridPoint 8
# ---------------------------------
# GridPoint 9
# ---------------------------------
# GridPoint 10
# ---------------------------------
# GridPoint 11
# ---------------------------------
# GridPoint 12
# ---------------------------------
# GridPoint 13
# ---------------------------------
# GridPoint 14
# ---------------------------------
# GridPoint 15
# ---------------------------------
# GridPoint 16
# ---------------------------------
# GridPoint 17
# ---------------------------------
# GridPoint 18
# ---------------------------------
# GridPoint 19
# ---------------------------------
# GridPoint 20
# ---------------------------------
# GridPoint 21
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445327      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 22
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445328      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 23
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445329      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 24
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445330      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 25
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445331      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 26
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445332      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 27
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445333      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 28
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445334      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 29
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445335      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 30
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445336      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 31
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445337      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 32
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445338      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 33
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445339      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 34
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445340      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 35
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445341      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 36
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445342      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 37
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445343      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 38
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445344      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 39
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445345      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 40
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445346      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 41
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445347      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 42
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445348      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 43
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445349      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 44
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445350      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 45
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445351      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 46
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445352      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 47
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445353      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 48
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445354      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------
# GridPoint 49
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445355      CLIMB-GP-+     p.vera        mia          0    PENDING      0:0
# ---------------------------------

# %%
print(restart_job_ids)
# Out:
# [[21, '1445327'], [22, '1445328'], [23, '1445329'], [24, '1445330'], [25, '1445331'], [26, '1445332'], [27, '1445333'], [28, '1445334'], [29, '1445335'], [30, '1445336'], [31, '1445337'], [32, '1445338'], [33, '1445339'], [34, '1445340'], [35, '1445341'], [36, '1445342'], [37, '1445343'], [38, '1445344'], [39, '1445345'], [40, '1445346'], [41, '1445347'], [42, '1445348'], [43, '1445349'], [44, '1445350'], [45, '1445351'], [46, '1445352'], [47, '1445353'], [48, '1445354'], [49, '1445355']]

# %%
# cancle the pending jobs
for gp, job_id in restart_job_ids:
    print(gp, job_id)
    os.system(f"scancel {job_id}")
# Out:
# 21 1445327
# 22 1445328
# 23 1445329
# 24 1445330
# 25 1445331
# 26 1445332
# 27 1445333
# 28 1445334
# 29 1445335
# 30 1445336
# 31 1445337
# 32 1445338
# 33 1445339
# 34 1445340
# 35 1445341
# 36 1445342
# 37 1445343
# 38 1445344
# 39 1445345
# 40 1445346
# 41 1445347
# 42 1445348
# 43 1445349
# 44 1445350
# 45 1445351
# 46 1445352
# 47 1445353
# 48 1445354
# 49 1445355

# %%
assert False, "don't run this"
# change the number of nodes and allowed time for the previously cancled jobs
for gp, job_id in restart_job_ids:
    run_gridpoint_path = run_location + f"/gridpoint{gp}"
    
    path_to_slurm_script = run_gridpoint_path + "/script.slurm"
    
    file_content = []
    with open(path_to_slurm_script, "r", encoding="utf-8") as file:
        for row in file:
            if "SBATCH --nodes=" in row:
                row = f"#SBATCH --nodes=1\n"
            file_content.append(row)

    with open(path_to_slurm_script, "w") as file:
        for row in file_content:
            file.write(row)
            
    path_to_param_file = run_gridpoint_path + "/param_L25n128.txt"
    
    file_content = []
    with open(path_to_param_file, "r") as file:
        for row in file:
            if "TimeLimitCPU" in row:
                row = f"TimeLimitCPU           36000\n"
            file_content.append(row)

    with open(path_to_param_file, "w") as file:
        for row in file_content:
            file.write(row)

# %%
assert False, "Don't run this again either"
# resubmit the jobs
for gp, job_id in restart_job_ids:
    run_gridpoint_path = run_location + f"/gridpoint{gp}"
    os.chdir(run_gridpoint_path)
    
    slurm_script = "script.slurm"
    result = subprocess.run(["sbatch", slurm_script], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    sbatch_output = result.stdout.strip()
    
    with open(run_location+"/slurm_job_ids.txt", "a") as myfile:
        myfile.write(f"{gp}: {sbatch_output}\n")
# Out:
# skipping 21

# %%
# check up on status
successfull_runs = []
with open(run_location+"/slurm_job_ids.txt", "r") as file:
    for row in file:
        count = int(row.split()[0][:-1])
        job_id = row.split()[-1]
        print("GridPoint", count)
        result = subprocess.run(["sacct", "-j", f"{job_id}"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
        sbatch_output = result.stdout.strip()
        if not "FAILED" in sbatch_output and not "PENDING" in sbatch_output and not "CANCELLED" in sbatch_output and not "RUNNING" in sbatch_output:
            print(sbatch_output)
            successfull_runs.append(count)
        print("---------------------------------")
print(successfull_runs)

# %%
# check status of all runs:
completed_runs = []
failed_runs = []
cancelled_runs = []
still_running = []
pending_runs = []

with open(run_location+"/slurm_job_ids.txt", "r") as file:
    for row in file:
        count = int(row.split()[0][:-1])
        job_id = row.split()[-1]
        print("GridPoint", count)
        result = subprocess.run(["sacct", "-j", f"{job_id}"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
        sbatch_output = result.stdout.strip()
        
        if "FAILED" in sbatch_output:
            print("Failed")
            print(sbatch_output)
            failed_runs.append(count)
        elif "CANCELLED" in sbatch_output:
            print("Cancelled")
            print(sbatch_output)
            cancelled_runs.append(count)
        elif "RUNNING" in sbatch_output:
            print("running")
            print(sbatch_output)
            still_running.append(count)
        elif "PENDING" in sbatch_output:
            print("pending")
            print(sbatch_output)
            pending_runs.append(count)
        if not "FAILED" in sbatch_output and not "PENDING" in sbatch_output and not "CANCELLED" in sbatch_output and not "RUNNING" in sbatch_output:
            print("success")
            print(sbatch_output)
            completed_runs.append(count)
        print("---------------------------------")
# Out:
# GridPoint 0
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445306      CLIMB-GP-0     p.vera        mia        288  COMPLETED      0:0
# 1445306.bat+      batch                   mia         72  COMPLETED      0:0
# 1445306.ext+     extern                   mia        288  COMPLETED      0:0
# 1445306.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 1
# Failed
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445307      CLIMB-GP-1     p.vera        mia        288     FAILED      9:0
# 1445307.bat+      batch                   mia         72     FAILED      9:0
# 1445307.ext+     extern                   mia        288  COMPLETED      0:0
# 1445307.0    Arepo_L25+                   mia        288 CANCELLED+      0:9
# ---------------------------------
# GridPoint 2
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445308      CLIMB-GP-2     p.vera        mia        288  COMPLETED      0:0
# 1445308.bat+      batch                   mia         72  COMPLETED      0:0
# 1445308.ext+     extern                   mia        288  COMPLETED      0:0
# 1445308.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 3
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445309      CLIMB-GP-3     p.vera        mia        288  COMPLETED      0:0
# 1445309.bat+      batch                   mia         72  COMPLETED      0:0
# 1445309.ext+     extern                   mia        288  COMPLETED      0:0
# 1445309.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 4
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445310      CLIMB-GP-4     p.vera        mia        288  COMPLETED      0:0
# 1445310.bat+      batch                   mia         72  COMPLETED      0:0
# 1445310.ext+     extern                   mia        288  COMPLETED      0:0
# 1445310.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 5
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445311      CLIMB-GP-5     p.vera        mia        288  COMPLETED      0:0
# 1445311.bat+      batch                   mia         72  COMPLETED      0:0
# 1445311.ext+     extern                   mia        288  COMPLETED      0:0
# 1445311.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 6
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445312      CLIMB-GP-6     p.vera        mia        288  COMPLETED      0:0
# 1445312.bat+      batch                   mia         72  COMPLETED      0:0
# 1445312.ext+     extern                   mia        288  COMPLETED      0:0
# 1445312.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 7
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445313      CLIMB-GP-7     p.vera        mia        288  COMPLETED      0:0
# 1445313.bat+      batch                   mia         72  COMPLETED      0:0
# 1445313.ext+     extern                   mia        288  COMPLETED      0:0
# 1445313.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 8
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445314      CLIMB-GP-8     p.vera        mia        288  COMPLETED      0:0
# 1445314.bat+      batch                   mia         72  COMPLETED      0:0
# 1445314.ext+     extern                   mia        288  COMPLETED      0:0
# 1445314.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 9
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445315      CLIMB-GP-9     p.vera        mia        288  COMPLETED      0:0
# 1445315.bat+      batch                   mia         72  COMPLETED      0:0
# 1445315.ext+     extern                   mia        288  COMPLETED      0:0
# 1445315.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 10
# Failed
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445316      CLIMB-GP-+     p.vera        mia        288     FAILED      9:0
# 1445316.bat+      batch                   mia         72     FAILED      9:0
# 1445316.ext+     extern                   mia        288  COMPLETED      0:0
# 1445316.0    Arepo_L25+                   mia        288     FAILED      1:0
# ---------------------------------
# GridPoint 11
# Failed
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445317      CLIMB-GP-+     p.vera        mia        288     FAILED      9:0
# 1445317.bat+      batch                   mia         72     FAILED      9:0
# 1445317.ext+     extern                   mia        288  COMPLETED      0:0
# 1445317.0    Arepo_L25+                   mia        288 CANCELLED+      0:9
# ---------------------------------
# GridPoint 12
# Failed
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445318      CLIMB-GP-+     p.vera        mia        288     FAILED      9:0
# 1445318.bat+      batch                   mia         72     FAILED      9:0
# 1445318.ext+     extern                   mia        288  COMPLETED      0:0
# 1445318.0    Arepo_L25+                   mia        288     FAILED      1:0
# ---------------------------------
# GridPoint 13
# Failed
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445319      CLIMB-GP-+     p.vera        mia        288     FAILED      9:0
# 1445319.bat+      batch                   mia         72     FAILED      9:0
# 1445319.ext+     extern                   mia        288  COMPLETED      0:0
# 1445319.0    Arepo_L25+                   mia        288 CANCELLED+      0:9
# ---------------------------------
# GridPoint 14
# Failed
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445320      CLIMB-GP-+     p.vera        mia        288     FAILED      9:0
# 1445320.bat+      batch                   mia         72     FAILED      9:0
# 1445320.ext+     extern                   mia        288  COMPLETED      0:0
# 1445320.0    Arepo_L25+                   mia        288 CANCELLED+      0:9
# ---------------------------------
# GridPoint 15
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445321      CLIMB-GP-+     p.vera        mia        288  COMPLETED      0:0
# 1445321.bat+      batch                   mia         72  COMPLETED      0:0
# 1445321.ext+     extern                   mia        288  COMPLETED      0:0
# 1445321.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 16
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445322      CLIMB-GP-+     p.vera        mia        288  COMPLETED      0:0
# 1445322.bat+      batch                   mia         72  COMPLETED      0:0
# 1445322.ext+     extern                   mia        288  COMPLETED      0:0
# 1445322.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 17
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445323      CLIMB-GP-+     p.vera        mia        288  COMPLETED      0:0
# 1445323.bat+      batch                   mia         72  COMPLETED      0:0
# 1445323.ext+     extern                   mia        288  COMPLETED      0:0
# 1445323.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 18
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445324      CLIMB-GP-+     p.vera        mia        288  COMPLETED      0:0
# 1445324.bat+      batch                   mia         72  COMPLETED      0:0
# 1445324.ext+     extern                   mia        288  COMPLETED      0:0
# 1445324.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 19
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445325      CLIMB-GP-+     p.vera        mia        288  COMPLETED      0:0
# 1445325.bat+      batch                   mia         72  COMPLETED      0:0
# 1445325.ext+     extern                   mia        288  COMPLETED      0:0
# 1445325.0    Arepo_L25+                   mia        288  COMPLETED      0:0
# ---------------------------------
# GridPoint 20
# Failed
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445326      CLIMB-GP-+     p.vera        mia        288     FAILED      9:0
# 1445326.bat+      batch                   mia         72     FAILED      9:0
# 1445326.ext+     extern                   mia        288  COMPLETED      0:0
# 1445326.0    Arepo_L25+                   mia        288     FAILED      1:0
# ---------------------------------
# GridPoint 21
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445327      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 22
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445328      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 23
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445329      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 24
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445330      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 25
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445331      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 26
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445332      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 27
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445333      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 28
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445334      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 29
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445335      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 30
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445336      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 31
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445337      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 32
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445338      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 33
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445339      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 34
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445340      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 35
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445341      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 36
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445342      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 37
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445343      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 38
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445344      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 39
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445345      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 40
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445346      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 41
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445347      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 42
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445348      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 43
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445349      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 44
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445350      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 45
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445351      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 46
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445352      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 47
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445353      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 48
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445354      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 49
# Cancelled
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445355      CLIMB-GP-+     p.vera        mia          0 CANCELLED+      0:0
# ---------------------------------
# GridPoint 21
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445378      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445378.bat+      batch                   mia         72  COMPLETED      0:0
# 1445378.ext+     extern                   mia         72  COMPLETED      0:0
# 1445378.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 22
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445379      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445379.bat+      batch                   mia         72  COMPLETED      0:0
# 1445379.ext+     extern                   mia         72  COMPLETED      0:0
# 1445379.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 23
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445380      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445380.bat+      batch                   mia         72  COMPLETED      0:0
# 1445380.ext+     extern                   mia         72  COMPLETED      0:0
# 1445380.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 24
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445381      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445381.bat+      batch                   mia         72  COMPLETED      0:0
# 1445381.ext+     extern                   mia         72  COMPLETED      0:0
# 1445381.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 25
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445382      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445382.bat+      batch                   mia         72  COMPLETED      0:0
# 1445382.ext+     extern                   mia         72  COMPLETED      0:0
# 1445382.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 26
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445383      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445383.bat+      batch                   mia         72  COMPLETED      0:0
# 1445383.ext+     extern                   mia         72  COMPLETED      0:0
# 1445383.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 27
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445384      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445384.bat+      batch                   mia         72  COMPLETED      0:0
# 1445384.ext+     extern                   mia         72  COMPLETED      0:0
# 1445384.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 28
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445385      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445385.bat+      batch                   mia         72  COMPLETED      0:0
# 1445385.ext+     extern                   mia         72  COMPLETED      0:0
# 1445385.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 29
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445386      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445386.bat+      batch                   mia         72  COMPLETED      0:0
# 1445386.ext+     extern                   mia         72  COMPLETED      0:0
# 1445386.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 30
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445387      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445387.bat+      batch                   mia         72  COMPLETED      0:0
# 1445387.ext+     extern                   mia         72  COMPLETED      0:0
# 1445387.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 31
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445388      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445388.bat+      batch                   mia         72  COMPLETED      0:0
# 1445388.ext+     extern                   mia         72  COMPLETED      0:0
# 1445388.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 32
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445389      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445389.bat+      batch                   mia         72  COMPLETED      0:0
# 1445389.ext+     extern                   mia         72  COMPLETED      0:0
# 1445389.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 33
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445390      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445390.bat+      batch                   mia         72  COMPLETED      0:0
# 1445390.ext+     extern                   mia         72  COMPLETED      0:0
# 1445390.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 34
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445391      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445391.bat+      batch                   mia         72  COMPLETED      0:0
# 1445391.ext+     extern                   mia         72  COMPLETED      0:0
# 1445391.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 35
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445392      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445392.bat+      batch                   mia         72  COMPLETED      0:0
# 1445392.ext+     extern                   mia         72  COMPLETED      0:0
# 1445392.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 36
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445393      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445393.bat+      batch                   mia         72  COMPLETED      0:0
# 1445393.ext+     extern                   mia         72  COMPLETED      0:0
# 1445393.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 37
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445394      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445394.bat+      batch                   mia         72  COMPLETED      0:0
# 1445394.ext+     extern                   mia         72  COMPLETED      0:0
# 1445394.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 38
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445395      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445395.bat+      batch                   mia         72  COMPLETED      0:0
# 1445395.ext+     extern                   mia         72  COMPLETED      0:0
# 1445395.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 39
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445396      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445396.bat+      batch                   mia         72  COMPLETED      0:0
# 1445396.ext+     extern                   mia         72  COMPLETED      0:0
# 1445396.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 40
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445397      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445397.bat+      batch                   mia         72  COMPLETED      0:0
# 1445397.ext+     extern                   mia         72  COMPLETED      0:0
# 1445397.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 41
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445398      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445398.bat+      batch                   mia         72  COMPLETED      0:0
# 1445398.ext+     extern                   mia         72  COMPLETED      0:0
# 1445398.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 42
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445399      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445399.bat+      batch                   mia         72  COMPLETED      0:0
# 1445399.ext+     extern                   mia         72  COMPLETED      0:0
# 1445399.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 43
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445400      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445400.bat+      batch                   mia         72  COMPLETED      0:0
# 1445400.ext+     extern                   mia         72  COMPLETED      0:0
# 1445400.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 44
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445401      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445401.bat+      batch                   mia         72  COMPLETED      0:0
# 1445401.ext+     extern                   mia         72  COMPLETED      0:0
# 1445401.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 45
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445402      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445402.bat+      batch                   mia         72  COMPLETED      0:0
# 1445402.ext+     extern                   mia         72  COMPLETED      0:0
# 1445402.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 46
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445403      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445403.bat+      batch                   mia         72  COMPLETED      0:0
# 1445403.ext+     extern                   mia         72  COMPLETED      0:0
# 1445403.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 47
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445404      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445404.bat+      batch                   mia         72  COMPLETED      0:0
# 1445404.ext+     extern                   mia         72  COMPLETED      0:0
# 1445404.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 48
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445405      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445405.bat+      batch                   mia         72  COMPLETED      0:0
# 1445405.ext+     extern                   mia         72  COMPLETED      0:0
# 1445405.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 49
# success
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1445406      CLIMB-GP-+     p.vera        mia         72  COMPLETED      0:0
# 1445406.bat+      batch                   mia         72  COMPLETED      0:0
# 1445406.ext+     extern                   mia         72  COMPLETED      0:0
# 1445406.0    Arepo_L25+                   mia         72  COMPLETED      0:0
# ---------------------------------
# GridPoint 1
# running
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1472083      CLIMB-GP-1     p.vera        mia         72    RUNNING      0:0
# 1472083.bat+      batch                   mia         72    RUNNING      0:0
# 1472083.ext+     extern                   mia         72    RUNNING      0:0
# 1472083.0    Arepo_L25+                   mia         72    RUNNING      0:0
# ---------------------------------
# GridPoint 10
# running
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1472084      CLIMB-GP-+     p.vera        mia         72    RUNNING      0:0
# 1472084.bat+      batch                   mia         72    RUNNING      0:0
# 1472084.ext+     extern                   mia         72    RUNNING      0:0
# 1472084.0    Arepo_L25+                   mia         72    RUNNING      0:0
# ---------------------------------
# GridPoint 11
# running
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1472085      CLIMB-GP-+     p.vera        mia         72    RUNNING      0:0
# 1472085.bat+      batch                   mia         72    RUNNING      0:0
# 1472085.ext+     extern                   mia         72    RUNNING      0:0
# 1472085.0    Arepo_L25+                   mia         72    RUNNING      0:0
# ---------------------------------
# GridPoint 12
# running
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1472086      CLIMB-GP-+     p.vera        mia         72    RUNNING      0:0
# 1472086.bat+      batch                   mia         72    RUNNING      0:0
# 1472086.ext+     extern                   mia         72    RUNNING      0:0
# 1472086.0    Arepo_L25+                   mia         72    RUNNING      0:0
# ---------------------------------
# GridPoint 13
# running
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1472087      CLIMB-GP-+     p.vera        mia         72    RUNNING      0:0
# 1472087.bat+      batch                   mia         72    RUNNING      0:0
# 1472087.ext+     extern                   mia         72    RUNNING      0:0
# 1472087.0    Arepo_L25+                   mia         72    RUNNING      0:0
# ---------------------------------
# GridPoint 14
# running
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1472088      CLIMB-GP-+     p.vera        mia         72    RUNNING      0:0
# 1472088.bat+      batch                   mia         72    RUNNING      0:0
# 1472088.ext+     extern                   mia         72    RUNNING      0:0
# 1472088.0    Arepo_L25+                   mia         72    RUNNING      0:0
# ---------------------------------
# GridPoint 20
# running
# JobID           JobName  Partition    Account  AllocCPUS      State ExitCode
# ------------ ---------- ---------- ---------- ---------- ---------- --------
# 1472089      CLIMB-GP-+     p.vera        mia         72    RUNNING      0:0
# 1472089.bat+      batch                   mia         72    RUNNING      0:0
# 1472089.ext+     extern                   mia         72    RUNNING      0:0
# 1472089.0    Arepo_L25+                   mia         72    RUNNING      0:0
# ---------------------------------

# %%
print(f"Completed runs: {len(completed_runs)}")
print(f"Failed runs: {len(failed_runs)}")
print(f"Cancelled runs: {len(cancelled_runs)}")
print(f"Still running: {len(still_running)}")
print(f"Pending runs: {len(pending_runs)}")
# Out:
# Completed runs: 43
# Failed runs: 7
# Cancelled runs: 29
# Still running: 7
# Pending runs: 0

# %%
import numpy as np
grid_csv_file_path = "/vera/u/jerbo/code/TNG-arepo-scripts/grid_lhs_constrained.csv"
grid_point_indices = [i for i in failed_runs]

with open(grid_csv_file_path, newline='') as f:
    reader = csv.reader(f, delimiter=',')
    header = next(reader, None)
    interestingrows=[row for idx, row in enumerate(reader) if idx in grid_point_indices]

for i in range(len(interestingrows)):
    for j in range(len(interestingrows[i])):
        interestingrows[i][j] = float(interestingrows[i][j])
    
interestingrows = np.array(interestingrows).T
print("-------------- Analysis of failed runs --------------")
for i, x in enumerate(interestingrows):
    print("Parameter:", header[i])
    print(f"Mean = {x.mean():.5f}")
    print(f"std  = {x.std():.5f}")
    print("")
    print("List of values:")
    print(x)
    print("-----------------------------")
# Out:
# -------------- Analysis of failed runs --------------
# Parameter: Omega_m
# Mean = 0.30609
# std  = 0.09630
#
# List of values:
# [0.18197366 0.4000871  0.46034819 0.29241471 0.17873135 0.30162545
#  0.32745956]
# -----------------------------
# Parameter: Omega_b
# Mean = 0.03481
# std  = 0.03341
#
# List of values:
# [0.00377535 0.03442523 0.08735444 0.01024164 0.00473946 0.08334695
#  0.01978955]
# -----------------------------
# Parameter: Omega_Lambda
# Mean = 0.69391
# std  = 0.09630
#
# List of values:
# [0.81802634 0.5999129  0.53965181 0.70758529 0.82126865 0.69837455
#  0.67254044]
# -----------------------------
# Parameter: Hubble_parameter
# Mean = 0.69114
# std  = 0.06973
#
# List of values:
# [0.70464209 0.77791124 0.6579378  0.59117156 0.66112296 0.64401232
#  0.80117703]
# -----------------------------

# %%
assert False, "Dont run this again"
for gp in failed_runs:
    run_gridpoint_path = run_location + f"/gridpoint{gp}"
    
    path_to_slurm_script = run_gridpoint_path + "/script.slurm"
    
    file_content = []
    with open(path_to_slurm_script, "r", encoding="utf-8") as file:
        for row in file:
            if "SBATCH --nodes=" in row:
                row = f"#SBATCH --nodes=1\n"
            file_content.append(row)

    with open(path_to_slurm_script, "w") as file:
        for row in file_content:
            file.write(row)
            
    path_to_param_file = run_gridpoint_path + "/param_L25n128.txt"
    
    file_content = []
    with open(path_to_param_file, "r") as file:
        for row in file:
            if "TimeLimitCPU" in row:
                row = f"TimeLimitCPU           36000\n"
            file_content.append(row)

    with open(path_to_param_file, "w") as file:
        for row in file_content:
            file.write(row)

# %%
assert False
#os.chdir("/vera/ptmp/gc/jerbo/babysitter_script_test_playground")
#assert os.getcwd() == "/vera/ptmp/gc/jerbo/babysitter_script_test_playground"
os.system("rm -rf /vera/ptmp/gc/jerbo/babysitter_script_test_playground/test_folder/*")

# %%
assert False
for gp in failed_runs:
    out_gridpoint_path = output_location + f"/gridpoint{gp}"
    cmd = f"rm -rf {out_gridpoint_path}/*"
    print(cmd)
    os.system(cmd)
# Out:
# rm -rf /vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint1/*
# rm -rf /vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint10/*
# rm -rf /vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint11/*
# rm -rf /vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint12/*
# rm -rf /vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint13/*
# rm -rf /vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint14/*
# rm -rf /vera/u/jerbo/my_ptmp/L25n128_suite/gridpoint20/*

# %%
assert False, "Dont run this again"
for gp in failed_runs:
    run_gridpoint_path = run_location + f"/gridpoint{gp}"
    os.chdir(run_gridpoint_path)
    
    slurm_script = "script.slurm"
    result = subprocess.run(["sbatch", slurm_script], stdout=subprocess.PIPE, stderr=subprocess.PIPE, universal_newlines=True)
    sbatch_output = result.stdout.strip()
    
    with open(run_location+"/slurm_job_ids.txt", "a") as myfile:
        myfile.write(f"{gp}: {sbatch_output}\n")
